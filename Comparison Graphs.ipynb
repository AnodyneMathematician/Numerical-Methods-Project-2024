timesq2=[ 3600.0, 56410.0, 1.5605e6, 1.2022242e8, 2.7129456e9, 2.012208786e11, 1.3477929654e12, 1.5151911558e12]
timesq3=[2190.0, 50250.0, 2.14095e6, 7.695913e7, 8.5871254e8, 1.239470999e11, 8.7629105e10, 2.6648696294e12]
timesq4=[3540.0, 46040.0, 650170.0, 2.76135e7, 8.43428575e8, 1.688407235e11, 8.643118977e11, 4.0773887544e12]
timesq5=[5430.0, 211230.0, 3.90829e6, 2.650898e7, 2.3014849e9, 1.854312207e11, 4.7635021839e12, 9.942812042e11]
timesq6=[5100.0, 61550.0, 8.13554e6, 2.2840658e8, 1.30244614e10, 9.233220663e11, 3.499512663e11, 4.659113556e11]
avgtimesq=(timesq1.+timesq2.+timesq3.+timesq4.+timesq5.+timesq6)/6


errorsq=[]
for i in 1:8
    sd = std([timesq1[i],timesq2[i],timesq3[i],timesq4[i],timesq5[i],timesq6[i]])
    push!(errorsq, sd)  
end

errosq = abs.(errorsq.-avgtimesq)
# Out:
# 8-element Vector{Float64}:
#    2831.696134267565
#   24583.070293312703
#  386572.75782634784
#       2.6359918843517885e7
#       1.2944508223931842e9
#       4.647796565349298e11
#       4.2748068608323804e11
#       3.135923837955364e11

# %%
# Arnoldi Best Fit
data = DataFrame(X=msize, Y=avgtimesa)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  2.30617    0.266767   8.64    0.0001    1.65341    2.95893
# log10(X)     5.23445    0.189415  27.63    <1e-06    4.77096    5.69793
# ───────────────────────────────────────────────────────────────────────

# %%
# QR Best Fit
data = DataFrame(X=msize, Y=avgtimesq)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  1.77933    0.240338   7.40    0.0003    1.19124    2.36742
# log10(X)     5.34844    0.17065   31.34    <1e-07    4.93087    5.766
# ───────────────────────────────────────────────────────────────────────

# %%
a = (msize.^5.23445).*10^2.30617
q = (msize.^5.34844).*10^1.77933

ys, xs = [avgtimesa - errosa; reverse(avgtimesa + errosa)], [msize; reverse(msize)]
plot(xs, ys, st=:shape, fc=:blues, lw=0, label=false)

ys, xs = [avgtimesq - errosq; reverse(avgtimesq + errosq)], [msize; reverse(msize)]
plot!(xs, ys, st=:shape, fc=:lightgreen, lw=0, label=false)

plot!(msize,avgtimesa,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:blue,yerror=errosa,label="Arnoldi")


plot!(msize,avgtimesq,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:green,yerror=errosq,label="QR")
plot!(msize, a, linecolor=:blue, label=L"x^{5.23445}\times 10^{2.30617}")
plot!(msize,q, linecolor=:green,label=L"x^{5.34844}\times 10^{1.77933}")

xlabel!(L"$N\times N$ matrix")
ylabel!("Average Time, nano seconds")
title!("(0% Sparsity) Arnoldi vs QR")
plot!(legend=:topleft)

# %%
msize=[4,8,16,32,64,80,100]
timesa1=[65420.0, 3.10703e6, 1.9202739e8, 1.8536497e10, 3.082391048e11, 2.445849617e11, 2.017790191e12]
timesa2=[48360.0, 64900.0, 1.6976197e8, 6.71516052e10, 5.275123882e11, 3.4726728273e12, 1.6847202633e12]
timesa3=[83000.0, 2.94356e6, 2.7182055e8, 1.06627021e10, 2.65765962e10, 3.604973636e11, 5.942924839e11]
timesa4=[106900.0, 325010.0, 2.4163466e9, 3.0560436e9, 2.1957802137e12, 1.3082082485e12, 4.0629539819e12]
timesa5=[69130.0, 598980.0, 2.1639571e8, 9.3524866e9, 1.05436532e11, 6.4175864473e12, 1.2173657478e12]
timesa6=[32800.0, 1.364229e7, 9.282702e7, 3.5552926e9, 1.194777465e11, 4.03018736e11, 8.86520355e11]
avgtimesa=(timesa1.+timesa2.+timesa3.+timesa4.+timesa5.+timesa6)/6


errorsa=[]
for i in 1:7
    sd = std([timesa1[i],timesa2[i],timesa3[i],timesa4[i],timesa5[i],timesa6[i]])
    push!(errorsa, sd)
end

errosa = abs.(errorsa.-avgtimesa)

timesq1=[10480.0, 4.69779e6, 2.255219e7, 9.7833075e9, 8.6617678e10, 1.399956202e11, 3.9776369149e12]
timesq2=[6500.0, 452250.0, 2.552632e7, 1.1145936333333333e9, 1.35964462e10, 5.214200394e11, 9.499139304e11]
timesq3=[13980.0, 2.58133e6, 1.3982432e8, 8.5663186e8, 5.558836069e11, 2.4106318506e12, 3.4554918609e12]
timesq4=[15050.0, 619400.0, 8.240748e7, 2.5989676e9, 8.49216159e10, 2.781706702e11, 2.313519682e12]
timesq5=[23090.0, 2.17919e6, 5.310708e7, 8.9718289e9, 8.28280063e10, 3.2780347626e12, 1.6314075968e12]
timesq6=[119330.0, 2.39553e6, 1.2410937e8, 1.9089395e9, 2.462558307e11, 1.8534943989e12, 6.312625057e11]
avgtimesq=(timesq1.+timesq2.+timesq3.+timesq4.+timesq5.+timesq6)/6


errorsq=[]
for i in 1:7
    sd = std([timesq1[i],timesq2[i],timesq3[i],timesq4[i],timesq5[i],timesq6[i]])
    push!(errorsq, sd)  
end

errosq = abs.(errorsq.-avgtimesq)
# Out:
# 7-element Vector{Float64}:
#   12021.204416227767
#  607419.3432711912
#       2.4897770809976928e7
#       1.4483514296130753e8
#       2.1926623699722473e10
#       1.1971965050994507e11
#       8.118047346758035e11

# %%
data = DataFrame(X=msize, Y=avgtimesa)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  1.7349     0.381797   4.54    0.0061   0.753464    2.71634
# log10(X)     5.49509    0.25431   21.61    <1e-05   4.84136     6.14881
# ───────────────────────────────────────────────────────────────────────

# %%
data = DataFrame(X=msize, Y=avgtimesq)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  1.11687    0.163618   6.83    0.0010   0.696277    1.53746
# log10(X)     5.66773    0.108984  52.01    <1e-07   5.38757     5.94788
# ───────────────────────────────────────────────────────────────────────

# %%
a = (msize.^5.49509).*10^1.7349
q = (msize.^5.66773).*10^1.11687

ys, xs = [avgtimesa - errosa; reverse(avgtimesa + errosa)], [msize; reverse(msize)]
plot(xs, ys, st=:shape, fc=:blues, lw=0, label=false)

ys, xs = [avgtimesq - errosq; reverse(avgtimesq + errosq)], [msize; reverse(msize)]
plot!(xs, ys, st=:shape, fc=:lightgreen, lw=0, label=false)

plot!(msize,avgtimesa,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:blue,yerror=errosa,label="Arnoldi")
plot!(msize, a, linecolor=:blue, label="")


plot!(msize,avgtimesq,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:green,yerror=errosq,label="QR")
plot!(msize,q, linecolor=:green,label="")

xlabel!(L"$N\times N$ matrix")
ylabel!("Average Time, nano seconds")
title!("(75% Sparsity) Arnoldi vs QR")
plot!(legend=:topleft)

# %%
msize = [10,25,50,100,200,400,800,1000]  

timesa1=[544660.0, 3.61615e6, 7.96532e6, 9.576696e7, 3.2810178e8, 3.4615101e9, 6.4701108e10, 1.453075748e11]
timesa2=[57400.0, 2.8307e6, 6.30758e6, 6.204206e7, 5.766761e8, 4.5512241e9, 1.268098442e11, 2.944224804e11]
timesa3=[66200.0, 1.41697e6, 1.825671e7, 6.382117e7, 4.8717135e8, 4.7884873e9, 6.45851678e10, 1.496721054e11]
timesa4=[61940.0, 2.67068e6, 1.189485e7, 4.750685e7, 4.2354609e8, 9.1569796e9, 1.502024277e11, 2.877554679e11]
timesa5=[71380.0, 1.21711e6, 1.043666e7, 8.726847e7, 6.204178142857143e8, 5.9378639e9, 6.41776923e10, 2.889398241e11]
timesa6=[124190.0, 1.32541e6, 7.20647e6, 6.761035e7, 4.3155967e8, 9.2283844e9, 6.19314677e10, 1.450048283e11]
avgtimesa=(timesa1.+timesa2.+timesa3.+timesa4.+timesa5.+timesa6)/6


errorsa=[]
for i in 1:8
    sd = std([timesa1[i],timesa2[i],timesa3[i],timesa4[i],timesa5[i],timesa6[i]])
    push!(errorsa, sd)
end

errosa = abs.(errorsa.-avgtimesa)

timesq1= [125100.0,2.90005e6, 4.297173e7, 6.407705428571428e8,4.6695923e9,1.080244622e11,1.0792843592e12, 3.9685923638e12] 
timesq2= [2.3704e6, 2.26879e6, 5.19385e7,2.991788e8,5.1146494e9, 1.084617911e11,1.0805497345e12, 3.9787298273e12]
timesq3= [1.942e6, 1.9696e6, 3.61793e7, 2.3528098e8, 4.2828363e9, 9.65467033e10, 1.7113893119e12, 3.7368548321e12]
timesq4= [1.2041e6, 3.43624e6, 3.943791e7, 3.6053182e8, 6.0384684e9, 1.224723773e11, 1.5785911614e12,3.673377829e12]
timesq5 = [1.34152e6, 4.61134e6, 4.892903e7, 3.6674256e8, 6.0709649e9, 1.933871134e11, 1.5911119523e12,3.6637627619e12]
timesq6 = [547490.0, 4.69598e6, 3.794899e7, 4.768902e8, 7.2939906e9, 1.170808057e11, 1.4962727817e12, 2.8364684667e12]
avgtimesq=(timesq1.+timesq2.+timesq3.+timesq4.+timesq5.+timesq6)/6


errorsq=[]
for i in 1:8
    sd = std([timesq1[i],timesq2[i],timesq3[i],timesq4[i],timesq5[i],timesq6[i]])
    push!(errorsq, sd)  
end

errosq = abs.(errorsq.-avgtimesq)
# Out:
# 8-element Vector{Float64}:
#  418034.5213929637
#       2.157887132885822e6
#       3.6580859353155464e7
#       2.5250134549252144e8
#       4.472341436744795e9
#       8.935897794278755e10
#       1.1484872313445088e12
#       3.223588466432735e12

# %%
data = DataFrame(X=msize, Y=avgtimesa)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  1.95067    0.249698   7.81    0.0002    1.33968    2.56166
# log10(X)     3.04937    0.11261   27.08    <1e-06    2.77382    3.32491
# ───────────────────────────────────────────────────────────────────────

# %%
data = DataFrame(X=msize, Y=avgtimesq)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  2.04576    0.416997   4.91    0.0027    1.02541    3.06612
# log10(X)     3.43365    0.188059  18.26    <1e-05    2.97349    3.89382
# ───────────────────────────────────────────────────────────────────────

# %%
a = (msize.^3.04937).*10^1.95067 
q = (msize.^3.43365).*10^2.04576 

ys, xs = [avgtimesa - errosa; reverse(avgtimesa + errosa)], [msize; reverse(msize)]
plot(xs, ys, st=:shape, fc=:blues, lw=0, label=false)

ys, xs = [avgtimesq - errosq; reverse(avgtimesq + errosq)], [msize; reverse(msize)]
plot!(xs, ys, st=:shape, fc=:lightgreen, lw=0, label=false)

plot!(msize,avgtimesa,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:blue,yerror=errosa,label="Arnoldi")
plot!(msize, a, linecolor=:blue, label="")


plot!(msize,avgtimesq,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:green,yerror=errosq,label="QR")
plot!(msize,q, linecolor=:green,label="")

xlabel!(L"$N\times N$ matrix")
ylabel!("Average Time, nano seconds")
title!("(Sparsity 10) Arnoldi vs QR")
plot!(legend=:topleft)

# %%
msize=[8,16,32,64,80,100]
timesa1=[ 4.56498e6, 8.845209e8, 1.262998136e11, 2.2494530575e12, 8.13452993e10, 3.5966422346e12]
timesa2=[ 708620.0, 1.73361585e9, 1.21490856e10, 7.44053277e10, 5.313302287e11, 1.2074416092e12]
timesa3=[ 1.097951e7, 3.474861e7, 5.5271172e9, 9.40631805e10, 1.84159339e11, 2.4507259399e12]
timesa4=[ 9.93537e6, 1.2396017e8, 7.4891421e9, 5.369891267e11, 1.414884314e11, 4.6643845259e12]
timesa5=[ 3.626836e7, 3.8416683e8, 1.04685558e10, 2.421986993e11, 1.5467491548e12, 1.40936389869e13]
timesa6=[ 2.94791e6, 2.04170455e9, 5.768634e9, 2.6042987103e12, 1.1440542895e12, 6.742654998e12]
avgtimesa=(timesa1.+timesa2.+timesa3.+timesa4.+timesa5.+timesa6)/6

timesk34a1=[5.85901e6, 1.0370657e8, 2.824154e8, 2.705744841e11, 6.95041287e10, 1.203682756e11]
timesk34a2=[495450.0, 4.489461e7, 2.33127695e9, 3.07349672e10, 1.905251455e11, 1.828077163e11]
timesk34a3=[7.4335e7, 7.78691e7, 3.7575839e9, 4.94050588e10, 2.380582037e11, 2.121907311e11]
timesk34a4=[431520.0, 9.70931e6, 8.603647e8, 7.370639058e11, 4.063014541e11, 8.8240822897e12]
timesk34a5=[3.32399e6, 8.835479e7, 2.7958490666666665e9, 9.72132971e10, 2.98271953e10, 1.603673285e11]
timesk34a6=[593190.0, 1.0297663e8, 2.1937514666666665e9, 1.52304122e10, 7.33993311e10, 2.195704245e11]
avgtimesk34a=(timesk34a1.+timesk34a2.+timesk34a3.+timesk34a4.+timesk34a5.+timesk34a6)/6

timesk2a1=[ 91640.0, 975710.0, 2.3480579e8, 3.9010311e9, 1.31692095e10, 3.00201573e10]
timesk2a2=[ 77460.0, 5.12816e6, 6.238529e7, 5.666334e9, 7.5101035e9, 3.22360831e10]
timesk2a3=[ 327210.0, 5.175604e7, 2.9620657e8, 5.0526148e9, 2.49973769e10, 5.28941175e10]
timesk2a4=[ 132570.0, 4.6567e6, 5.5736485e8, 6.0808413e9, 2.18570511e10, 1.792170128e11]
timesk2a5=[ 62600.0, 2.647914e7, 5.992415055555555e9, 3.9564598e9, 6.168175357e11, 1.169715034e11]
timesk2a6=[ 59390.0, 1.89643e6, 8.7015236e9, 2.6728057e9, 5.5574939e10, 5.82425288e10]
avgtimesk2a=(timesk2a1.+timesk2a2.+timesk2a3.+timesk2a4.+timesk2a5.+timesk2a6)/6

timesk4a1=[7060.0, 75460.0, 4.57262e6, 1.4419325e8, 8.2544364e8, 4.5195675e9]
timesk4a2=[6250.0, 44590.0, 1.912584e7, 1.9296096e8, 4.4448559e8, 1.23486678e9]
timesk4a3=[3870.0, 78680.0, 1.125772e7, 9.997925e7, 6.9953552e8, 5.8719018e9]
timesk4a4=[3790.0, 48150.0, 5.37757e7, 3.1132855e8, 2.6944209e8, 1.13530642e9]
timesk4a5=[6710.0, 38040.0, 1.74978e6, 1.4972108e9, 3.6753327e8, 1.8318023666666667e9]
timesk4a6= [7090.0, 113080.0,9.55895e7, 1.6146143e8, 1.03128091e10, 3.1294717e9]
avgtimesk4a=(timesk4a1.+timesk4a2.+timesk4a3.+timesk4a4.+timesk4a5.+timesk4a6)/6


timesq1=[ 2.09343e6, 2.1857653e8, 1.01326375e9, 3.4239438084e12, 4.889480314e11, 5.915932645e11]
timesq2=[ 1.5605e6, 1.2022242e8, 2.7129456e9, 2.012208786e11, 1.3477929654e12, 1.5151911558e12]
timesq3=[ 2.14095e6, 7.695913e7, 8.5871254e8, 1.239470999e11, 8.7629105e10, 2.6648696294e12]
timesq4=[ 650170.0, 2.76135e7, 8.43428575e8, 1.688407235e11, 8.643118977e11, 4.0773887544e12]
timesq5=[ 3.90829e6, 2.650898e7, 2.3014849e9, 1.854312207e11, 4.7635021839e12, 9.942812042e11]
timesq6=[ 8.13554e6, 2.2840658e8, 1.30244614e10, 9.233220663e11, 3.499512663e11, 4.659113556e11]
avgtimesq=(timesq1.+timesq2.+timesq3.+timesq4.+timesq5.+timesq6)/6;

# %%
data = DataFrame(X=msize, Y=avgtimesa)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  2.78905    0.510023   5.47    0.0054    1.373      4.2051
# log10(X)     4.95534    0.318195  15.57    <1e-04    4.07188    5.83879
# ───────────────────────────────────────────────────────────────────────

# %%
data = DataFrame(X=msize, Y=avgtimesk2a)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────
# (Intercept)  0.735585    0.959327  0.77    0.4860   -1.92793    3.39911
# log10(X)     5.24899     0.598509  8.77    0.0009    3.58726    6.91071
# ───────────────────────────────────────────────────────────────────────

# %%
data = DataFrame(X=msize, Y=avgtimesk4a)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────
# (Intercept)  -1.35679    0.644554  -2.11    0.1031   -3.14636   0.432774
# log10(X)      5.53808    0.402127  13.77    0.0002    4.42159   6.65456
# ────────────────────────────────────────────────────────────────────────

# %%
data = DataFrame(X=msize, Y=avgtimesq)
lm(@formula(log10(Y)~log10(X)), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# :(log10(Y)) ~ 1 + :(log10(X))
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error      t  Pr(>|t|)   Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────
# (Intercept)  1.39067    0.515395   2.70    0.0542  -0.0402955    2.82164
# log10(X)     5.58136    0.321547  17.36    <1e-04   4.6886       6.47412
# ────────────────────────────────────────────────────────────────────────

# %%
a = (msize.^4.95534).*10^2.78905
q = (msize.^5.58136).*10^1.39067 
ak2 = (msize.^5.24899).*10^0.735585
ak4 = (msize.^5.53808).*10^-1.35679

plot(msize,avgtimesa,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:cyan,label=L"Arnoldi, $k=N$")
plot!(msize, a, label="", linecolor=:cyan)

plot!(msize,avgtimesq,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:green,label="QR")
plot!(msize,q, linecolor=:green,label="")


plot!(msize,avgtimesk2a,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:blue,label=L"Arnoldi, $k=N/2$")
plot!(msize,ak2,xaxis=:log10,yaxis=:log10,linecolor=:blue,label="")

plot!(msize,avgtimesk4a,xaxis=:log10,yaxis=:log10,seriestype=:scatter,color=:lightblue,label=L"Arnoldi, $k=N/4$")
plot!(msize,ak4,xaxis=:log10,yaxis=:log10,linecolor=:lightblue,label="")


xlabel!(L"$N\times N$ matrix")
ylabel!("Average Time, nano seconds")
title!("(0% Sparsity) Arnoldi vs QR")
plot!(legend=:topleft)
